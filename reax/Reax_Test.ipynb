# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sympy import * 
from statistics import mean

file = pd.read_csv("log.lammps",delim_whitespace = True,skiprows=108,skipfooter=30,names=["Step","PotEng","KinEng","TotEng","Temp","Volume","Press"])
print(file)
# Out:
#         Step     PotEng      KinEng     TotEng         Temp  Volume  \
# 0     100000 -9065.8967    3.238675 -9062.6580    10.447197  125000
# 1     110000 -9054.5485   36.869439 -9017.6791   118.932040  125000
# 2     120000 -9058.6462   42.094174 -9016.5520   135.785800  125000
# 3     130000 -9050.6035   41.073161 -9009.5303   132.492250  125000
# 4     140000 -9045.2122   58.881791 -8986.3304   189.938660  125000
# ..       ...        ...         ...        ...          ...     ...
# 96   1060000 -8965.1925  585.540730 -8379.6517  1888.815200  125000
# 97   1070000 -8972.8078  599.311760 -8373.4960  1933.237300  125000
# 98   1080000 -8951.5872  630.750440 -8320.8367  2034.651000  125000
# 99   1090000 -8926.4437  581.292950 -8345.1508  1875.112900  125000
# 100  1100000 -8954.9424  670.689630 -8284.2527  2163.485300  125000
#
#           Press
# 0     -1.493390
# 1     36.308146
# 2      7.394387
# 3     57.160336
# 4     -8.211409
# ..          ...
# 96   265.993030
# ...

# %%
Temp = np.array(file["Temp"])
P = np.array(file["Press"])
PEng = np.array(file["PotEng"])
KEng = np.array(file["KinEng"])
TEng = np.array(file["TotEng"])


plt.scatter(Temp,TEng);
plt.xlabel("Temperature [K]");
plt.ylabel("TotEng (eV)");

# %%
plt.scatter(Temp,PEng);
plt.xlabel("Temperature [K]");
plt.ylabel("PotEng (eV)");

# %%
plt.scatter(Temp,KEng);
plt.xlabel("Temperature [K]");
plt.ylabel("KinEng");

# %%
file = pd.read_csv("1000K.lammps",delim_whitespace = True,skiprows=108,skipfooter=30,names=["Step","PotEng","KinEng","TotEng","Temp","Volume","Press"])
file2 = pd.read_csv("1200K.lammps",delim_whitespace = True,skiprows=108,skipfooter=30,names=["Step","PotEng","KinEng","TotEng","Temp","Volume","Press"])
file3 = pd.read_csv("1400K.lammps",delim_whitespace = True,skiprows=108,skipfooter=30,names=["Step","PotEng","KinEng","TotEng","Temp","Volume","Press"])
file4 = pd.read_csv("1600K.lammps",delim_whitespace = True,skiprows=108,skipfooter=30,names=["Step","PotEng","KinEng","TotEng","Temp","Volume","Press"])
file5 = pd.read_csv("1800K.lammps",delim_whitespace = True,skiprows=108,skipfooter=30,names=["Step","PotEng","KinEng","TotEng","Temp","Volume","Press"])
file6 = pd.read_csv("2000K.lammps",delim_whitespace = True,skiprows=108,skipfooter=30,names=["Step","PotEng","KinEng","TotEng","Temp","Volume","Press"])
# Out:
# /ihome/crc/install/python/miniconda3-3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# /ihome/crc/install/python/miniconda3-3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#
# /ihome/crc/install/python/miniconda3-3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
Temp = np.array(file["Temp"])
P = np.array(file["Press"])
PEng = np.array(file["PotEng"])
PE2 = np.array(file2["PotEng"])
PE3 = np.array(file3["PotEng"])
PE4 = np.array(file4["PotEng"])
PE5 = np.array(file5["PotEng"])
PE6 = np.array(file6["PotEng"])
TEng = np.array(file["TotEng"])
V = np.array(file["Volume"])
Step = np.array(file["Step"])


plt.scatter(Temp[1:],TEng[1:]);
plt.xlabel("Temperature [K]");
plt.ylabel("TotEng (eV)");

# %%
plt.scatter(Temp[1:],PEng[1:]);
plt.xlabel("Temperature [K]");
plt.ylabel("PotEng (eV)");

# %%
plt.scatter(Temp,V);
plt.xlabel("Temperature [K]");
plt.ylabel("Volume");

# %%
plt.scatter(Temp,P);
plt.xlabel("Temperature [K]");
plt.ylabel("Pressure");

# %%
plt.scatter(Step[1:]*0.01,PEng[1:], label="1000K");
plt.scatter(Step[1:]*0.01,PE2[1:],label="1200K")
plt.scatter(Step[1:]*0.01,PE3[1:],label="1400K")
plt.scatter(Step[1:]*0.01,PE4[1:],label="1600K")
plt.scatter(Step[1:]*0.01,PE5[1:],label="1800K")
plt.scatter(Step[1:]*0.01,PE6[1:],label="2000K")
plt.xlabel("Time");
plt.ylabel("PotEng (eV)");
plt.legend()

# %%
invtime = 1/(Step*0.01)
invTemp = 1/
